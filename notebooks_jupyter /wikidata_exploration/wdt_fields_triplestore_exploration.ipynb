MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.0 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.7/2.0 MB 1.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 1.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.0 MB 1.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.1/2.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.0 MB 2.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
### Librairies externes à ajouter le cas échéant à l'environnement Python actif

from SPARQLWrapper import SPARQLWrapper, JSON, TURTLE, XML, RDFXML

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import networkx as nx

### Librairies déjà installées avec Python

import pprint
import csv
import sys

from importlib import reload

# %%
pip install itables
# Out:
# Requirement already satisfied: itables in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (2.4.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipython in c:\users\asus\appdata\roaming\python\python311\site-packages (from itables) (8.27.0)
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from itables) (2.1.1)
# Requirement already satisfied: pandas in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from itables) (2.3.0)
# Requirement already satisfied: decorator in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from ipython->itables) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from ipython->itables) (4.11.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from ipython->itables) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas->itables) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas->itables) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas->itables) (2025.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->itables) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\asus\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->itables) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->itables) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython->itables) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython->itables) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\asus\appdata\roaming\python\python311\site-packages (from stack-data->ipython->itables) (0.2.3)

# %%
### Module de visualisation de données
#  https://mwouts.github.io/itables/quick_start.html

from itables import init_notebook_mode, show

init_notebook_mode(all_interactive=False)
# Out:
# <script type="module">
#     const { set_or_remove_dark_class } = await import(window._datatables_src_for_itables_2_4_2);
#     set_or_remove_dark_class();
# </script>
# <style>:root, :host{--dt-row-selected: 13, 110, 253;--dt-row-selected-text: 255, 255, 255;--dt-row-selected-link: 9, 10, 11;--dt-row-stripe: 0, 0, 0;--dt-row-hover: 0, 0, 0;--dt-column-ordering: 0, 0, 0;--dt-html-background: white}:root.dark, :host.dark{--dt-html-background: rgb(33, 37, 41)}table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{display:inline-block;box-sizing:border-box;content:"";border-top:5px solid transparent;border-left:10px solid rgba(0,0,0,.5);border-bottom:5px solid transparent;border-right:0px solid transparent}table.dataTable tr.dt-hasChild td.dt-control:before{border-top:10px solid rgba(0,0,0,.5);border-left:5px solid transparent;border-bottom:0px solid transparent;border-right:5px solid transparent}table.dataTable tfoot:empty{display:none}html.dark table.dataTable td.dt-control:before, :root[data-bs-theme=dark] table.dataTable td.dt-control:before, :host[data-bs-theme=dark] table.dataTable td.dt-control:before, :root[data-theme=dark] table.dataTable td.dt-control:before, :host[data-theme=dark] table.dataTable td.dt-control:before{border-left-color:#ffffff80}html.dark table.dataTable tr.dt-hasChild td.dt-control:before, :root[data-bs-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before, :host[data-bs-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before, :root[data-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before, :host[data-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before{border-top-color:#ffffff80;border-left-color:transparent}div.dt-scroll{width:100%}div.dt-scroll-body thead tr,div.dt-scroll-body tfoot tr{height:0}div.dt-scroll-body thead tr th,div.dt-scroll-body thead tr td,div.dt-scroll-body tfoot tr th,div.dt-scroll-body tfoot tr td{height:0!important;padding-top:0!important;padding-bottom:0!important;border-top-width:0px!important;border-bottom-width:0px!important}div.dt-scroll-body thead tr th div.dt-scroll-sizing,div.dt-scroll-body thead tr td div.dt-scroll-sizing,div.dt-scroll-body tfoot tr th div.dt-scroll-sizing,div.dt-scroll-body tfoot tr td div.dt-scroll-sizing{height:0!important;overflow:hidden!important}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order:before{position:absolute;display:block;bottom:50%;content:"\25b2";content:"\25b2"/""}table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order:after{position:absolute;display:block;top:50%;content:"\25bc";content:"\25bc"/""}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order{position:relative;width:12px;height:20px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:before,table.dataT ...

# %%
### Importer un module de fonctions crées ad hoc
##  ATTENTION : le fichier 'sparql_functions.py' doit se trouver 
#   dans un dossier qui se situe dans le chemin ('path') de recherche
#   vu par le présent carnet Jupyter afin que
#   l'importation fonctionne correctement

# Add parent directory to the path
sys.path.insert(0, '..')

### If you want to add the parent-parent directory,
sys.path.insert(0, '../..')


import sparql_functions as spqf

# %% [markdown]
# ## Importer les donnée à analyser

# %%
## define SPARQL enpoint
endpoint = "https://ag13s8z3wvmae0kr.allegrograph.cloud/repositories/rappers"

# %%
### Get and count persons fields

query = """PREFIX franzOption_defaultDatasetBehavior: <franz:rdf>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?field ?fieldLabel (COUNT(*) as ?n)
WHERE {
    GRAPH <https://github.com/Ziedellouzi/rappers/blob/main/graphs/wikidata-imported-data.md>
        {?item wdt:P101 ?field.
        # ?field rdfs:label ?occupLabel
        BIND(LCASE(?occupLabel) as ?fieldLabel)    
          }
}
GROUP BY ?field ?fieldLabel 
ORDER BY DESC(?n)
#LIMIT 30
"""

# %%
### Execute the query using the local custom fonctions
qr = spqf.get_json_sparql_result(endpoint,query)

# %%
### Count and inspect the available fields
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# 113
# [['http://www.wikidata.org/entity/Q6010', 'rapping', '91'],
#  ['http://www.wikidata.org/entity/Q638', 'music', '81'],
#  ['http://www.wikidata.org/entity/Q11895763', 'music composing', '35']]

# %%
### Transform the results into a dataframe
df_r = pd.DataFrame(r)
df_r.columns=['uri', 'label', 'effectif']
df_r['effectif'] = df_r.effectif.apply(lambda x : int(x))
df_r.head()
# Out:
#                                         uri            label  effectif
# 0      http://www.wikidata.org/entity/Q6010          rapping        91
# 1       http://www.wikidata.org/entity/Q638            music        81
# 2  http://www.wikidata.org/entity/Q11895763  music composing        35
# 3     http://www.wikidata.org/entity/Q11401          hip-hop        28
# 4     http://www.wikidata.org/entity/Q27939          singing        19

# %%
### Bar chart showing distribution by 'field': 
# 30 most frequent fields
ax = df_r['effectif'].head(30).sort_values(ascending=True)\
    .plot(kind='barh',rot=10, fontsize=10, figsize=(16,8))
y_labels = reversed(df_r.head(30).label.to_list())
ax.set_yticklabels(y_labels)
ax.bar_label(ax.containers[-1])
plt.xlabel('Effectif')
plt.title('Distribution des fields')
plt.show()

# %%
l= len(df_r[df_r['effectif'] == 1])
print(l)
# Out:
# 70

# %%
l= len(df_r[df_r['effectif'] < 10])
print(l)
# Out:
# 106

# %% [markdown]
# ### Graphically represent the frequency distribution

# %%
### Distribution des effectifs par field
ax = df_r.boxplot(column=['effectif'], vert=False, figsize=(16,4))

# %%
### Distribution des effectifs par occupation
ax = df_r[df_r.effectif<100].boxplot(column=['effectif'], vert=False, figsize=(16,4))
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %%
### Represent the density (the total surface has frequency = 1)
# https://seaborn.pydata.org/generated/seaborn.violinplot.html

plt.figure(figsize=(18,4))
d = df_r[df_r.effectif<100].effectif

ax = sns.violinplot(x = d)


### Noter que au delà des limites les valeurs sont coupées car postulées
ax.set_xlim(left=min(d), right=max(d))
plt.show()

# %% [markdown]
# ### Group by frequency range

# %%
### Set the thresholds

ls = [1, 5, 10, 20, 50, 100, 200, 300, 500, 1000, 30000]
print(ls)
# Out:
# [1, 5, 10, 20, 50, 100, 200, 300, 500, 1000, 30000]

# %%
### fonction pd.cut : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html
# On ajoute une nouvelle colonne qui contient la période sur la base de la liste précédente
# et de la valeur de l'année

df_r['seuils'] = pd.cut(df_r['effectif'], ls, right=False)

### Transformer le code ajouté pour qu'il soit plus lisible
# noter qu'on a arrondi les valeurs
df_r['seuils'] = df_r['seuils'].apply(lambda x : str(int(x.left))+'-'+ str(int(x.right)-1))

# Inspection
df_r.head(3)
# Out:
#                                         uri            label  effectif seuils
# 0      http://www.wikidata.org/entity/Q6010          rapping        91  50-99
# 1       http://www.wikidata.org/entity/Q638            music        81  50-99
# 2  http://www.wikidata.org/entity/Q11895763  music composing        35  20-49

# %%
# Plot the grouped distribution

ax = df_r.groupby(by='seuils', observed=False).size()\
    .plot(kind='bar',rot=10, fontsize=10, figsize=(10,8))
ax.bar_label(ax.containers[-1], fontsize=10)
plt.xlabel('Effectif de personnes avec telle occupation')
plt.title('Distribution des effectifs des occupations')
plt.show()

# %% [markdown]
# ### Inspect the values

# %%
print(df_r[df_r['effectif'] == 1].head(10).label)
# Out:
# 43                cosmetics
# 44    percussion instrument
# 45    electroacoustic music
# 46          hip hop culture
# 47              slam poetry
# 48               basketball
# 49                  chatbot
# 50                 painting
# 51                    humor
# 52        digital marketing
# Name: label, dtype: object

# %%
print(df_r[df_r['effectif'] == 5].head(10).label)
# Out:
# 11        music composition
# 12    composed musical work
# 13            popular music
# 14                pop music
# Name: label, dtype: object

# %%
print(df_r[df_r['effectif'] == 10].head(10).label)
# Out:
# Series([], Name: label, dtype: object)

# %%
### Bar chart representing the distribution by ‘occupation’ 
# in a given frequency range

d = df_r[(df_r.effectif < 100)&(df_r.effectif > 9)].sort_values(by='effectif',ascending=True).head(40)
ax = d.effectif.plot(kind='barh',rot=10, fontsize=10, figsize=(16,8))
y_labels = reversed(d.label.to_list())
ax.set_yticklabels(y_labels)
ax.bar_label(ax.containers[-1])
plt.xlabel('Effectif')
plt.title('Distribution des occupations')
plt.show()

# %%
print(df_r.columns)
# Out:
# Index(['uri', 'label', 'effectif', 'seuils'], dtype='object')

# %%
print(df_r.head())  # Affiche les premières lignes pour voir la structure des données
print(df_r['effectif'].describe())
# Out:
#                                         uri            label  effectif seuils
# 0      http://www.wikidata.org/entity/Q6010          rapping        91  50-99
# 1       http://www.wikidata.org/entity/Q638            music        81  50-99
# 2  http://www.wikidata.org/entity/Q11895763  music composing        35  20-49
# 3     http://www.wikidata.org/entity/Q11401          hip-hop        28  20-49
# 4     http://www.wikidata.org/entity/Q27939          singing        19  10-19
# count    113.000000
# mean       4.194690
# std       12.115411
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       91.000000
# Name: effectif, dtype: float64

# %%
print(len(df_r[df_r.effectif > 100]))
# Out:
# 0

# %% [markdown]
# # Remarque: j'ai changé le filtre effectif>100 par effectif > 50 car pas de valeur superieur à 100

# %%
### Bar chart representing the distribution by ‘occupation’ 
# in a given frequency range

d = df_r[df_r.effectif > 50].sort_values(by='effectif', ascending=True)
ax = d.effectif.plot(kind='barh',rot=10, fontsize=10, figsize=(16,8))
y_labels = reversed(d.label.to_list())
ax.set_yticklabels(y_labels)
ax.bar_label(ax.containers[-1])
plt.xlabel('Effectif')
plt.title('Distribution des occupations')
plt.show()

# %% [markdown]
# **Comment**
#
# ,,,

# %% [markdown]
# ## Explore the number of fields per person

# %%
### Basic query regarding persons' fields

query = """PREFIX franzOption_defaultDatasetBehavior: <franz:rdf>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?item ?itemLabel (COUNT(*) as ?n)
WHERE {
    GRAPH <https://github.com/Ziedellouzi/rappers/blob/main/graphs/wikidata-imported-data.md>
        {?item wdt:P101 ?field.
        OPTIONAL {?item rdfs:label ?itemLabel}    
          }
}
GROUP BY ?item ?itemLabel
ORDER BY DESC(?n)
#LIMIT 500
"""

# %%
### Executer la requête avec les fonctions de la librairie locale
qr = spqf.get_json_sparql_result(endpoint,query)

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# 227
# [['http://www.wikidata.org/entity/Q81942005', 'Zdeněk Veselý', '8'],
#  ['http://www.wikidata.org/entity/Q982674', 'Sir Mix-a-Lot', '8'],
#  ['http://www.wikidata.org/entity/Q238819', 'Jay Chou', '7']]

# %%
### Transform the results to a dataframe
df_r = pd.DataFrame(r)
df_r.columns=['uri', 'label', 'effectif']
df_r['effectif'] = df_r.effectif.apply(lambda x : int(x))
df_r.head()
# Out:
#                                         uri            label  effectif
# 0  http://www.wikidata.org/entity/Q81942005    Zdeněk Veselý         8
# 1    http://www.wikidata.org/entity/Q982674    Sir Mix-a-Lot         8
# 2    http://www.wikidata.org/entity/Q238819         Jay Chou         7
# 3  http://www.wikidata.org/entity/Q95371099    Ondřej Anděra         6
# 4   http://www.wikidata.org/entity/Q1532874  Chilly Gonzales         6

# %%
### Distribution of frequencies per person
ax = df_r.boxplot(column=['effectif'], vert=False, figsize=(16,4))

## this fuction avoids ticks with floats instead of integers
#  on the x axis
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# **Comment**
#
# Most persons have between 1 and 3 occupations, with some outliers

# %%
### Distribution des effectifs par occupation

d = df_r[df_r.effectif > 3]
print(len(d))

ax = d.boxplot(column=['effectif'], vert=False, figsize=(16,4))
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# 33

# %%
### Cf. the profiles of these persons in Wikidata
pprint.pprint(d.tail())
# Out:
#                                           uri           label  effectif
# 28     http://www.wikidata.org/entity/Q357645     Frank Ocean         4
# 29    http://www.wikidata.org/entity/Q1510159          Gerard         4
# 30  http://www.wikidata.org/entity/Q108619954  Shesha Sayanha         4
# 31     http://www.wikidata.org/entity/Q364214           Rakim         4
# 32    http://www.wikidata.org/entity/Q2530802   Volkan Türeli         4

# %% [markdown]
# ## Parent occupations
#
# We can try to use the taxonomy of occupations to select relevant occupations.
#
# We therefore go back to the [Import sparqlbook](../../sparqlbooks/wdt_import_occupations.sparqlbook)

# %%
query = """
## 

### Simplified query

PREFIX franzOption_defaultDatasetBehavior: <franz:rdf>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX bd: <http://www.bigdata.com/rdf#>

SELECT DISTINCT 
# ?occupation ?occupationLabel ?parentField ?parentFieldLabel
# ?n
          #?parentKnowledgeClassification ?parentKnowledgeClassificationLabel 
          # (SUM(?n) as ?sn)
WHERE {
    GRAPH <https://github.com/Ziedellouzi/rappers/blob/main/graphs/wikidata-imported-data.md>
        {
          SELECT ?occupation ?occupationLabel
          # ?parentOccupation (COUNT(*) as ?n)
        
        WHERE
        {
          # ?s a wd:Q5;  
              wdt:P106 ?occupation.
          # ?occupation rdfs:label ?occupationLabel.
          # ?occupation  wdt:P279  ?parentOccupation.
          }  
        GROUP BY ?occupation ?occupationLabel
          # ?parentOccupation
        }

        SERVICE <https://query.wikidata.org/sparql>
          {
              # field of parent occupation / instance of /  subclass of  
              # ?parentOccupation wdt:P425 / wdt:P31 ?parentField.
              # ?parentField wdt:P279 ?parentKnowledgeClassification.


              #BIND (?occupation as ?occupationLabel)
              BIND (?parentFieldLabel as ?parentFieldLabel)
              # BIND (?parentKnowledgeClassificationLabel as ?parentKnowledgeClassificationLabel)
              SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } 
          }

}
# GROUP BY ?occupation ?occupationLabel ?parentField ?parentFieldLabel
          # ?parentKnowledgeClassification ?parentKnowledgeClassificationLabel 
ORDER BY DESC(?n)
"""

# %%
### Executer la requête avec les fonctions de la librairie locale
qr = spqf.get_json_sparql_result(endpoint,query)

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# 374
# [['http://www.wikidata.org/entity/Q2252262',
#   'rapper',
#   'http://www.wikidata.org/entity/Q862597',
#   'musical form',
#   '8917'],
#  ['http://www.wikidata.org/entity/Q2252262',
#   'rapper',
#   'http://www.wikidata.org/entity/Q188451',
#   'music genre',
#   '8917'],
#  ['http://www.wikidata.org/entity/Q177220',
#   'singer',
#   'http://www.wikidata.org/entity/Q1047113',
#   'field of study',
#   '3314']]

# %%
### Transform the results to a dataframe
df_r = pd.DataFrame(r)
df_r.columns=['uriOccupation', 'labelOccupation', 'uriDomaine', 'labelDomain', 'size']
# df_r['size'] = df_r.size.apply(lambda x : int(x))
df_r.head()
# Out:
#                              uriOccupation labelOccupation  \
# 0  http://www.wikidata.org/entity/Q2252262          rapper
# 1  http://www.wikidata.org/entity/Q2252262          rapper
# 2   http://www.wikidata.org/entity/Q177220          singer
# 3   http://www.wikidata.org/entity/Q177220          singer
# 4   http://www.wikidata.org/entity/Q177220          singer
#
#                                  uriDomaine          labelDomain  size
# 0    http://www.wikidata.org/entity/Q862597         musical form  8917
# 1    http://www.wikidata.org/entity/Q188451          music genre  8917
# 2   http://www.wikidata.org/entity/Q1047113       field of study  3314
# 3   http://www.wikidata.org/entity/Q2267705       field of study  3314
# 4  http://www.wikidata.org/entity/Q11862829  academic discipline  3314

# %%
## [gb_oc['size'] > 4 ]

show(df_r,  scrollY="300px",
     scrollCollapse=True, paging=False, layout={"topEnd": None}, 
     showIndex=False, column_filters="header", # columnDefs=[{"className": "dt-left", "targets": "_all"}],
     search={"regex": True, "caseInsensitive": True},
     # https://mwouts.github.io/itables/downsampling.html
       maxBytes=0)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0e29385e_9eae_4564_b203_045a8d511d0c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the <code>init_notebook_mode</code> cell...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <script type="module">
#     const { ITable, jQuery: $ } = await import(window._datatables_src_for_itables_2_4_2);
#
#     document.querySelectorAll("#itables_0e29385e_9eae_4564_b203_045a8d511d0c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"scrollY": "300px", "scrollCollapse": true, "paging": false, "layout": {"topStart": "pageLength", "topEnd": null, "bottomStart": "info", "bottomEnd": "paging"}, "column_filters": "header", "search": {"regex": true, "caseInsensitive": true}, "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "table_html": "<table><thead><th>uriOccupation</th><th>labelOccupation</th><th>uriDomaine</th><th>labelDomain</th><th>size</th></thead></table>", "data_json": "[[\"http://www.wikidata.org/entity/Q2252262\", \"rapper\", \"http://www.wikidata.org/entity/Q862597\", \"musical form\", \"8917\"], [\"http://www.wikidata.org/entity/Q2252262\", \"rapper\", \"http://www.wikidata.org/entity/Q188451\", \"music genre\", \"8917\"], [\"http://www.wikidata.org/entity/Q177220\", \"singer\", \"http://www.wikidata.org/entity/Q1047113\", \"field of study\", \"3314\"], [\"http://www.wikidata.org/entity/Q177220\", \"singer\", \"http://www.wikidata.org/entity/Q2267705\", \"field of study\", \"3314\"], [\"http://www.wikidata.org/entity/Q177220\", \"singer\", \"http://www.wikidata.org/entity/Q11862829\", \"academic discipline\", \"3314\"], [\"http://www.wikidata.org/entity/Q177220\", \"singer\", \"http://www.wikidata.org/entity/Q56055944\", \"type of arts\", \"3314\"], [\"http://www.wikidata.org/entity/Q177220\", \"singer\", \"http://www.wikidata.org/entity/Q862597\", \"musical form\", \"3314\"], [\"http://www.wikidata.org/entity/Q177220\", \"singer\", \"http://www.wikidata.org/entity/Q188451\", \"music genre\", \"3314\"], [\"http://www.wikidata.org/entity/Q753110\", \"songwriter\", \"http://www.wikidata.org/entity/Q11862829\", \"academic discipline\", \"2370\"], [\"http://www.wikidata.org/entity/Q753110\", \"songwriter\", \"http://www.wikidata.org/entity/Q116474095\", \"type of work of art\", \"2370\"], [\"http://www.wikidata.org/entity/Q753110\", \"songwriter\", \"http://www.wikidata.org/entity/Q1914636\", \"activity\", \"2370\"], [\"http://www.wikidata.org/entity/Q753110\", \"songwriter\", \"http://www.wikidata.org/entity/Q56055944\", \"type of arts\", \"2370\"], [\"http://www.wikidata.org/entity/Q753110\", \"songwriter\", \"http://www.wikidata.org/entity/Q11177771\", \"artistic technique\", \"2370\"], [\"http://www.wikidata.org/entity/Q183945\", \"record producer\", \"http://www.wikidata.org/entity/Q1047113\", \"field of study\", \"1482\"], [\"http://www.wikidata.org/entity/Q183945\", \"record producer\", \"http://www.wikidata.org/entity/Q2267705\", \"field of study\", \"1482\"], [\"http://www.wikidata.org/entity/Q183945\", \"record producer\", \"http://www.wikidata.org/entity/Q11862829\", \"academic discipline\", \"1482\"], [\"http://www.wikidata.org/entity/Q183945\", \"record producer\", \"http://www.wikidata.org/entity/Q56055944\", \"type of arts\", \"1482\"], [\"http://www.wikidata.org/entity/Q183945\", \"record producer\", \"http://www.wikidata.org/entity/Q8187769\", \"economic activity\", \"1482\"], [\"http://www.wikidata.org/entity/Q33999\", \"actor\", \"http://www.wikidata.org/entity/Q56055944\", \"type of arts\", \"1017\"], [\"http://www.wikidata.org/entity/Q639669\", \"musician\", \"http://www.wikidata.org/entity/Q627436\", \"field of work\", \"797\"], [\"http://www.wikidata.org/entity/Q639669\", \"musician\", \"http://www.wikidata.org/entity/Q3958441\", \"economic sector\", \"797\"], [\"http://www.wikidata.org/entity/Q639669\", \"musician\", \"http://www.wikidata.org/entity/Q576639\", \"essentially contested concept\", \"797\"], [\"http://www.wikidata.org/entity/Q639669\", \"musician\", \"http://www.wikidata.org/entity/Q4671286\", \"academic major\", \"797\"], [\"http://www.wikidata.org/entity/Q639669\", \"musician\", \"http://www.wikidata.org/entity/Q11862829\", \"academic discipline\", \"797\"], [\"http://www.wikidata.org/entity/Q639669\", \"musician\", \"http://www.wikidata.org/entity/Q26256810\ ...

# %%
query = """
### Occupation classifications

PREFIX franzOption_defaultDatasetBehavior: <franz:rdf>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?birthYear ?o ?oLabel ?oP ?oPLabel
WHERE {
    GRAPH <https://github.com/Ziedellouzi/rappers/blob/main/graphs/wikidata-imported-data.md>
        {?item a wd:Q5;
            wdt:P569 ?birthYear;
            wdt:P106 ?o.
        # ?o a wd:Q12737077;
            wdt:P279 ?o1.
        OPTIONAL {?o rdfs:label ?oLabel}    
        OPTIONAL {?oP rdfs:label ?oPLabel}    
          }
}
ORDER BY ?s 
"""

# %% [markdown]
# ci dessous j'ai rencontrer un probleme de memoire

# %%
### Executer la requête avec les fonctions de la librairie locale
qr = spqf.get_json_sparql_result(endpoint,query)
# Out:
# QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'QUERY MEMORY LIMIT REACHED: This AllegroGraph process is using or is about to use more memory than\nallowed.\n\nAn allocation request of 3.6 GiB would make private memory usage 7.8 GiB.  This\nis 100.4% of RAM, which exceeds the memoryExhaustionWarningPercentage\nquery option (90.0%).\n\nConsider restructuring your query or increasing the value of the\nmemoryExhaustionWarningPercentage query option. \n\nQuery is:\n\n### Occupation classifications\n\nPREFIX franzOption_defaultDatasetBehavior: <franz:rdf>\nPREFIX wd: <http://www.wikidata.org/entity/>\nPREFIX wdt: <http://www.wikidata.org/prop/direct/>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\n\nSELECT ?birthYear ?o ?oLabel ?oP ?oPLabel\nWHERE {\n    GRAPH <https://github.com/Ziedellouzi/rappers/blob/main/graphs/wikidata-imported-data.md>\n        {?item a wd:Q5;\n            wdt:P569 ?birthYear;\n            wdt:P106 ?o.\n        ?o a wd:Q12737077;\n            wdt:P279 ?o1.\n        OPTIONAL {?o rdfs:label ?oLabel}    \n        OPTIONAL {?oP rdfs:label ?oPLabel}    \n          }\n}\nORDER BY ?s \nLIMIT 1000\n\n\nQuery plan is:\nUsing bindings-set executor\nFinal plan:\n    (:modifiers\n    :project ?birthYear, ?o, ?oLabel, ?oP, ?oPLabel\n    (:graph {wikidata-imported-data.md}\n      (:left-join\n        (:lhs\n          (:join\n            (:lhs\n              (:graph current\n                (:triple-query <?o http://www.wikidata.org/prop/direct/P279 ?o1>\n                 :estimate 695.0 :cursor-estimate 695.0)\n                (:triple-query <?o rdf:type http://www.wikidata.org/entity/Q12737077>\n                 :estimate 695.0 :cursor-estimate 1044.9167)))\n            (:rhs\n              (:graph current\n                (:triple-query <?item rdf:type http://www.wikidata.org/entity/Q5>\n                 :estimate 1666.8334 :cursor-estimate 3063.4167)\n                (:triple-query <?item http://www.wikidata.org/prop/direct/P569 ?birthYear>\n                 :estimate 1678.4397 :cursor-estimate 4483.0)\n                (:triple-query <?item http://www.wikidata.org/prop/direct/P106 ?o>\n                 :estimate 5146.6504 :cursor-estimate 11843.0)\n                (:triple-query <?o rdfs:label ?oLabel>\n                 :estimate 695.2847 :cursor-estimate 4883.0 :optional)))))\n        (:rhs\n          (:graph current\n            (:triple-query <?oP rdfs:label ?oPLabel>\n            )))))\n    :order (asc ?s)\n    :limit 1,000)\nDataset\n  From      : 0 \n  From Named: 0  use default dataset behavior rdf\n\n\n\nVSZ 12.2 GiB, RSS 7.2 GiB, new 1.4 MiB, old 164.9 MiB, aclfree 6.9 GiB, aclused 4.0 GiB.'

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 r = [l for l in spqf.sparql_result_to_list(qr)]
#       2 print(len(r))
#       3 r[:3]
#
# File c:\Users\ASUS\Downloads\science humaine et historique\sparql_functions.py:41, in sparql_result_to_list(result)
#      38 def sparql_result_to_list (result):
#      40     i = 0
# ---> 41     variables = result['head']['vars']
#      42     result_l = []
#      44     for l in result['results']['bindings']:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
### Transform the results to a dataframe
df_r = pd.DataFrame(r)
df_r.columns=['year', 'oc_uri', 'oc_label', 'op_uri', 'op_label']
df_r['year'] = df_r.year.apply(lambda x : int(x))
df_r.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       2 df_r = pd.DataFrame(r)
#       3 df_r.columns=['year', 'oc_uri', 'oc_label', 'op_uri', 'op_label']
# ----> 4 df_r['year'] = df_r.year.apply(lambda x : int(x))
#       5 df_r.head()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)
#    4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)
#    4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[67], line 4, in <lambda>(x)
#       2 df_r = pd.DataFrame(r)
#       3 df_r.columns=['year', 'oc_uri', 'oc_label', 'op_uri', 'op_label']
# ----> 4 df_r['year'] = df_r.year.apply(lambda x : int(x))
#       5 df_r.head()
#
# ValueError: invalid literal for int() with base 10: 'http://www.wikidata.org/entity/Q2252262'

# %%
### distribution des naissances par périodes de 25 ans
gb_oc = df_r.groupby(by=['oc_label','op_label'], observed=False, as_index=False).size()
print(len(gb_oc))
gb_oc.head()
# Out:
# 281
#                                     oc_label op_label  size
# 0   http://www.wikidata.org/entity/Q10359055        1     1
# 1  http://www.wikidata.org/entity/Q104086571        2     1
# 2    http://www.wikidata.org/entity/Q1047113        1     8
# 3    http://www.wikidata.org/entity/Q1047113      100     1
# 4    http://www.wikidata.org/entity/Q1047113       11     1

# %%
## [gb_oc['size'] > 4 ]

show(gb_oc.sort_values(by='size', ascending=False),  scrollY="300px",
     scrollCollapse=True, paging=False, layout={"topEnd": None}, 
     showIndex=False, column_filters="header", columnDefs=[{"className": "dt-left", "targets": "_all"}],
     # https://mwouts.github.io/itables/downsampling.html
       maxBytes=0)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f0de5a82_fbca_4051_a503_a59c14cd7e15"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the <code>init_notebook_mode</code> cell...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <script type="module">
#     const { ITable, jQuery: $ } = await import(window._datatables_src_for_itables_2_4_2);
#
#     document.querySelectorAll("#itables_f0de5a82_fbca_4051_a503_a59c14cd7e15:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"scrollY": "300px", "scrollCollapse": true, "paging": false, "layout": {"topStart": "pageLength", "topEnd": null, "bottomStart": "info", "bottomEnd": "paging"}, "column_filters": "header", "columnDefs": [{"className": "dt-left", "targets": "_all"}], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "table_html": "<table><thead><th>oc_label</th><th>op_label</th><th>size</th></thead></table>", "data_json": "[[\"http://www.wikidata.org/entity/Q11862829\", \"1\", 11], [\"http://www.wikidata.org/entity/Q1047113\", \"1\", 8], [\"http://www.wikidata.org/entity/Q627436\", \"1\", 6], [\"http://www.wikidata.org/entity/Q8187769\", \"1\", 5], [\"http://www.wikidata.org/entity/Q1914636\", \"1\", 5], [\"http://www.wikidata.org/entity/Q11862829\", \"2\", 4], [\"http://www.wikidata.org/entity/Q2267705\", \"1\", 3], [\"http://www.wikidata.org/entity/Q1047113\", \"2\", 3], [\"http://www.wikidata.org/entity/Q56055944\", \"2\", 3], [\"http://www.wikidata.org/entity/Q11862829\", \"6\", 3], [\"http://www.wikidata.org/entity/Q56055944\", \"7\", 3], [\"http://www.wikidata.org/entity/Q2267705\", \"3\", 3], [\"http://www.wikidata.org/entity/Q11862829\", \"7\", 3], [\"http://www.wikidata.org/entity/Q483394\", \"2\", 3], [\"http://www.wikidata.org/entity/Q2465832\", \"1\", 3], [\"http://www.wikidata.org/entity/Q268592\", \"2\", 3], [\"http://www.wikidata.org/entity/Q4671286\", \"1\", 3], [\"http://www.wikidata.org/entity/Q4671286\", \"6\", 3], [\"http://www.wikidata.org/entity/Q11862829\", \"13\", 3], [\"http://www.wik
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX bd: <http://www.bigdata.com/rdf#>
PREFIX franzOption_defaultDatasetBehavior: <franz:rdf>

## Pour avoir les données avec la personne et l'effectif de toutes les relations
# SELECT DISTINCT ?item ?occupation ?occupationLabel ?occupation_1 ?occupation_1Label

SELECT ?occupation ?occupationLabel ?occupation_1 ?occupation_1Label
WHERE
  {GRAPH <https://github.com/Ziedellouzi/rappers/blob/main/graphs/wikidata-imported-data.md>
     {
      # ?item wdt:P106 ?occupation.
      # ?item wdt:P106 ?occupation_1.
      # ?occupation rdfs:label ?occupationLabel.
      # ?occupation_1 rdfs:label ?occupation_1Label.
      FILTER (str(?occupationLabel) < str(?occupation_1Label))
      } 

      }
"""

# %%
### Executer la requête avec les fonctions de la librairie locale
qr = spqf.get_json_sparql_result(endpoint,query)

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# 26331
# [['http://www.wikidata.org/entity/Q2252262',
#   'rapper',
#   'http://www.wikidata.org/entity/Q22813352',
#   'traveler'],
#  ['http://www.wikidata.org/entity/Q15253558',
#   'activist',
#   'http://www.wikidata.org/entity/Q22813352',
#   'traveler'],
#  ['http://www.wikidata.org/entity/Q4610556',
#   'model',
#   'http://www.wikidata.org/entity/Q1028181',
#   'painter']]

# %%
### Transform the results to a dataframe
df_r = pd.DataFrame(r)
df_r.columns=['uri', 'label', 'uri_1', 'label1_']
df_r.uri = df_r.uri.apply(lambda x : x.replace('http://www.wikidata.org/entity/', ''))
df_r.uri_1 = df_r.uri_1.apply(lambda x : x.replace('http://www.wikidata.org/entity/', ''))
df_r.head()
# Out:
#          uri       label      uri_1   label1_
# 0   Q2252262      rapper  Q22813352  traveler
# 1  Q15253558    activist  Q22813352  traveler
# 2   Q4610556       model   Q1028181   painter
# 3  Q10800557  film actor   Q1028181   painter
# 4     Q33999       actor     Q40348    lawyer

# %%
list(df_r.columns)
# Out:
# ['uri', 'label', 'uri_1', 'label1_']

# %%
gr = pd.DataFrame(df_r.groupby(['uri', 'label', 'uri_1', 'label1_']).size())
gr.reset_index(inplace=True)
gr.columns=list(df_r.columns)+['size']
gr.sort_values(by='size', ascending=False).head(40)
# Out:
#             uri            label      uri_1          label1_  size
# 608    Q2252262           rapper    Q177220           singer  3314
# 626    Q2252262           rapper    Q753110       songwriter  2370
# 465     Q177220           singer    Q753110       songwriter  1651
# 609    Q2252262           rapper    Q183945  record producer  1482
# 761      Q33999            actor   Q2252262           rapper  1017
# 1210    Q639669         musician   Q2252262           rapper   797
# 481     Q183945  record producer    Q753110       songwriter   784
# 469     Q183945  record producer    Q177220           singer   776
# 877      Q36834         composer   Q2252262           rapper   578
# 751      Q33999            actor    Q177220           singer   575
# 798      Q33999            actor    Q753110       songwriter   420
# 872      Q36834         composer    Q183945  record producer   348
# 58    Q10800557       film actor   Q2252262           rapper   295
# 1207    Q639669         musician    Q177220           singer   288
# 871      Q36834         composer    Q177220           singer   288
# 169     Q130857      disc jockey   Q2252262           rapper   286
# 752      Q33999            actor    Q183945  record producer   283
# 734      Q33999            actor  Q10800557       film actor   238
# 1170   Q5716684           dancer   Q2252262           rapper   224
# 1167   Q5716684           dancer    Q177220           singer   190
# 1229    Q639669         musician    Q753110       songwriter   181
# 166     Q130857      disc jockey    Q183945  record producer   174
# 205     Q131524     entrepreneur   Q2252262           rapper   166
# 1034   Q4610556            model   Q2252262           rapper   157
# 51    Q10800557       film actor    Q177220           singer   156
# 1208    Q639669         musician    Q183945  record producer   153
# 903      Q36834         composer    Q753110       songwriter   146
# 425   Q17125263         YouTuber   Q2252262           rapper   133
# 620    Q2252262           rapper     Q36180           writer   128
# 781      Q33999            actor     Q36834         composer   118
# 1031   Q4610556            model    Q177220           singer   117
# 224     Q131524     entrepreneur    Q753110       songwriter   115
# 74    Q10800557       film actor    Q753110       songwriter   115
# 165     Q130857      disc jockey    Q177220           singer   113
# 796      Q33999            actor    Q639669         musician   112
# 996      Q43845   businessperson   Q2252262           rapper   111
# 1125     Q49757             poet   Q2252262           rapper   103
# 52    Q10800557       film actor    Q183945  record producer   101
# 612    Q2252262           rapper   Q2405480      voice actor   100
# 616    Q2252262           rapper     Q28389     screenwriter    94

# %%
gr.sort_values(by='size', ascending=False).tail(40)
# Out:
#             uri                  label      uri_1             label1_  size
# 91     Q1113899  clinical psychologist    Q205375            inventor     1
# 1258    Q753110             songwriter   Q2914170       street artist     1
# 1259    Q753110             songwriter   Q2986228  sports commentator     1
# 1262    Q753110             songwriter     Q37226             teacher     1
# 1265    Q753110             songwriter     Q48282             student     1
# 1268     Q81096               engineer    Q183945     record producer     1
# 1270     Q81096               engineer   Q2914170       street artist     1
# 1287   Q8246794                blogger   Q3455803            director     1
# 65    Q10800557             film actor     Q33231        photographer     1
# 1257    Q753110             songwriter   Q2705098             tarento     1
# 44    Q10800557             film actor  Q12859263              orator     1
# 45    Q10800557             film actor   Q1320883      talent manager     1
# 46    Q10800557             film actor  Q13235160        manufacturer     1
# 49    Q10800557             film actor   Q1420621    media proprietor     1
# 50    Q10800557             film actor  Q15980158  non-fiction writer     1
# 1252    Q713200      performing artist     Q82955          politician     1
# 539    Q1979607              financier    Q753110          songwriter     1
# 540     Q201788              historian    Q177220              singer     1
# 36    Q10774753     performance artist    Q183945     record producer     1
# 54    Q10800557             film actor   Q1925963      graphic artist     1
# 55    Q10800557             film actor   Q1930187          journalist     1
# 56    Q10800557             film actor   Q1979607           financier     1
# 63    Q10800557             film actor   Q2914170       street artist     1
# 64    Q10800557             film actor   Q2986228  sports commentator     1
# 31     Q1075651            keyboardist     Q33231        photographer     1
# 32     Q1075651            keyboardist   Q3391743       visual artist     1
# 34    Q10774753     performance artist  Q13590141           presenter     1
# 533    Q1930187             journalist  Q94498772        program host     1
# 535    Q1979607              financier    Q177220              singer     1
# 536    Q1979607              financier   Q2252262              rapper     1
# 537    Q1979607              financier   Q2405480         voice actor     1
# 538    Q1979607              financier     Q36180              writer     1
# 16     Q1028181                painter     Q49757                poet     1
# 18    Q10384029        drug trafficker    Q131524        entrepreneur     1
# 19    Q10384029        drug trafficker    Q177220              singer     1
# 23     Q1062433              chanteuse  Q10800557          film actor     1
# 24     Q1062433              chanteuse    Q183945     record producer     1
# 25     Q1062433              chanteuse   Q2252262              rapper     1
# 26     Q1062433              chanteuse     Q36834            composer     1
# 27     Q1075651            keyboardist   Q1643514      music arranger     1

# %%
### Distribution des effectifs par occupation
ax = gr.boxplot(column=['size'], vert=False, figsize=(16,4))

# %%
### Distribution des effectifs par occupation
ax = gr[(gr['size']>10) & (gr['size']<500)].boxplot(column=['size'], vert=False, figsize=(16,4))

# %%
ax = gr['size'].plot(kind='bar',rot=10, fontsize=10, figsize=(10,8))
ax.bar_label(ax.containers[-1], fontsize=10)
plt.xlabel('Effectif de personnes avec telle occupation')
plt.title('Distribution des effectifs des occupations')
plt.show()

# %%
plt.figure(figsize=(15, 4))
d = gr[(gr['size'] > 0) & (gr['size'] < 10)]['size']
#d = gr['size']


ax = sns.barplot(x = d)
ax.set_xlim(left=min(d), right=max(d))

ax.plot()
# Out:
# []

# %%
show(gr[gr['size'] > 4 ].sort_values(by='size', ascending=False),  scrollY="300px",
     scrollCollapse=True, paging=False, layout={"topEnd": None}, 
     showIndex=False, column_filters="header", columnDefs=[{"className": "dt-left", "targets": "_all"}],
     # https://mwouts.github.io/itables/downsampling.html
       maxBytes=0)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f01a2941_239b_408b_b55d_3be4f36a868b"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the <code>init_notebook_mode</code> cell...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <script type="module">
#     const { ITable, jQuery: $ } = await import(window._datatables_src_for_itables_2_4_2);
#
#     document.querySelectorAll("#itables_f01a2941_239b_408b_b55d_3be4f36a868b:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"scrollY": "300px", "scrollCollapse": true, "paging": false, "layout": {"topStart": "pageLength", "topEnd": null, "bottomStart": "info", "bottomEnd": "paging"}, "column_filters": "header", "columnDefs": [{"className": "dt-left", "targets": "_all"}], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "table_html": "<table><thead><th>uri</th><th>label</th><th>uri_1</th><th>label1_</th><th>size</th></thead></table>", "data_json": "[[\"Q2252262\", \"rapper\", \"Q177220\", \"singer\", 3314], [\"Q2252262\", \"rapper\", \"Q753110\", \"songwriter\", 2370], [\"Q177220\", \"singer\", \"Q753110\", \"songwriter\", 1651], [\"Q2252262\", \"rapper\", \"Q183945\", \"record producer\", 1482], [\"Q33999\", \"actor\", \"Q2252262\", \"rapper\", 1017], [\"Q639669\", \"musician\", \"Q2252262\", \"rapper\", 797], [\"Q183945\", \"record producer\", \"Q753110\", \"songwriter\", 784], [\"Q183945\", \"record producer\", \"Q177220\", \"singer\", 776], [\"Q36834\", \"composer\", \"Q2252262\", \"rapper\", 578], [\"Q33999\", \"actor\", \"Q177220\", \"singer\", 575], [\"Q33999\", \"actor\", \"Q753110\", \"songwriter\", 420], [\"Q36834\", \"composer\", \"Q183945\", \"record producer\", 348], [\"Q10800557\", \"film actor\", \"Q2252262\", \"rapper\", 295], [\"Q639669\", \"musician\", \"Q177220\", \"singer\", 288], [\"Q36834\", \"composer\", \"Q177220\", \"singer\", 288], [\"Q130857\", \"disc jockey\", \"Q2252262\", \"rapper\", 286], [\"Q33999\", \"actor\", \"Q183945\", \"record producer\", 283], [\"Q33999\", \"actor\", \"Q10800557\", \"film actor\", 238], [\"Q5716684\", \"dancer\", \"Q2252262\", \"rapper\", 224], [\"Q5716684\", \"dancer\", \"Q177220\", \"singer\", 190], [\"Q639669\", \"musician\", \"Q753110\", \"songwriter\", 181], [\"Q130857\", \"disc jockey\", \"Q183945\", \"record producer\", 174], [\"Q131524\", \"entrepreneur\", \"Q2252262\", \"rapper\", 166], [\"Q4610556\", \"model\", \"Q2252262\", \"rapper\", 157], [\"Q10800557\", \"film actor\", \"Q177220\", \"singer\", 156], [\"Q639669\", \"musician\", \"Q183945\", \"record producer\", 153], [\"Q36834\", \"composer\", \"Q753110\", \"songwriter\", 146], [\"Q17125263\", \"YouTuber\", \"Q2252262\", \"rapper\", 133], [\"Q2252262\", \"rapper\", \"Q36180\", \"writer\", 128], [\"Q33999\", \"actor\", \"Q36834\", \"composer\", 118], [\"Q4610556\", \"model\", \"Q177220\", \"singer\", 117], [\"Q131524\", \"entrepreneur\", \"Q753110\", \"songwriter\", 115], [\"Q10800557\", \"film actor\", \"Q753110\", \"songwriter\", 115], [\"Q130857\", \"disc jockey\", \"Q177220\", \"singer\", 113], [\"Q33999\", \"actor\", \"Q639669\", \"musician\", 112], [\"Q43845\", \"businessperson\", \"Q2252262\", \"rapper\", 111], [\"Q49757\", \"poet\", \"Q2252262\", \"rapper\", 103], [\"Q10800557\", \"film actor\", \"Q183945\", \"record producer\", 101], [\"Q2252262\", \"rapper\", \"Q2405480\", \"voice actor\", 100], [\"Q2252262\", \"rapper\", \"Q28389\", \"screenwriter\", 94], [\"Q131524\", \"entrepreneur\", \"Q183945\", \"record producer\", 93], [\"Q131524\", \"entrepreneur\", \"Q177220\", \"singer\", 92], [\"Q33999\", \"actor\", \"Q5716684\", \"dancer\", 88], [\"Q130857\", \"disc jockey\", \"Q753110\", \"songwriter\", 87], [\"Q33999\", \"actor\", \"Q4610556\", \"model\", 85], [\"Q5716684\", \"dancer\", \"Q753110\", \"songwriter\", 85], [\"Q3922505\", \"DJ producer\", \"Q2252262\", \"rapper\", 81], [\"Q36834\", \"composer\", \"Q639669\", \"musician\", 80], [\"Q33999\", \"actor\", \"Q2405480\", \"voice actor\", 73], [\"Q43845\", \"businessperson\", \"Q753110\", \"songwriter\", 72], [\"Q15253558\", \"activist\", \"Q2252262\", \"rapper\", 69], [\"Q2252262\", \"rapper\", \"Q947873\", \"television presenter\", 68], [\"Q4610556\", \"model\", \"Q753110\", \"songwriter\", 67], [\"Q33999\", \"actor\", \"Q131524\", \"entrepreneur\", 67], [\"Q36834\", \"composer\", \"Q130857\", \"disc jockey\", 65] ...

# %% [markdown]
# ## Graphe

# %%
l = []
for _, i in gr[gr['size'] > 10].iterrows():  # Utiliser .iterrows() pour accéder à chaque ligne
    l.append(tuple((i['uri'], i['uri_1'])))  # Créer un tuple pour chaque ligne
l[:5]
# Out:
# [('Q100493654', 'Q2252262'),
#  ('Q1028181', 'Q2252262'),
#  ('Q10800557', 'Q177220'),
#  ('Q10800557', 'Q183945'),
#  ('Q10800557', 'Q2252262')]
